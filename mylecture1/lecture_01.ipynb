# %% [markdown]
# font size change

# %% [markdown]
# <font size = "10">
# hello world

# %% [markdown]
# Test

# %% [markdown]
# # Big Text

# %% [markdown]
# ##### Smaller text

# %%
print("Hello world")
# Out:
# Hello world
